# %% [markdown]
# # Columbia's Finance
#
# Has Bollinger's Manhattanville plans affected financial aid spending?

# %%
# %%capture

import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams.update({'font.size': 14})
plt.tight_layout()

# %% [markdown]
# ## Financial aid grants

# %%
grants = {
    2017: 432690000, # For the year ended June 30, 2018
    2016: 395016000,
    2015: 361839000, 
    2014: 344693000,
    2013: 327884000,
    2012: 315262000,
    2011: 298949000,
    2010: 282102000,
    2009: 260410000,
    2008: 237918000,
    2007: 237918000,
    2006: 237918000,
    2005: 173328000,
}

# Source: https://finance.columbia.edu/content/columbia-university-financial-reports

# %%
years = [i for i in range(2005, 2018)]

plt.figure(figsize=(8,8))
plt.plot(years, [grants[y] for y in years])
plt.ylim(bottom=0)
# Out:
# (0, 445658100.0)
